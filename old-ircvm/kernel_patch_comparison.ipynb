# %% [markdown]
# Kernel patch performance comparison

# %%
from typing import List, Optional
from enum import Enum
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns

# %%
runs = {}

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 1
Migrate splitted pages enabled : 1
Reset counters on splitted pages enabled : 1



Aggregated results :
Time (mean ± σ):      9.018 s ±  0.111 s    [User: 569.100 s, System: 2.784 s]
Range (min … max):    8.820 s …  9.260 s    20 runs
"""

runs["all"] = [
    8.8198657301,
    8.881893696099999,
    8.9255137181,
    8.9366588781,
    8.9512036961,
    8.962894282099999,
    8.9639812911,
    9.2603994531,
    9.0844907841,
    9.0560388011,
    8.9948493161,
    8.9947943481,
    8.9184912631,
    8.969600311099999,
    9.068269426099999,
    9.0467329421,
    9.2414346191,
    9.1305104141,
    9.1028847481,
    9.0488814121
    ]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 0

Split shared node pages enabled : 0
Reapply PROT_NONE on splitted pages enabled : 0
Migrate splitted pages enabled : 0
Reset counters on splitted pages enabled : 0

Aggregated results :
Time (mean ± σ):     10.231 s ±  0.093 s    [User: 650.629 s, System: 0.892 s]
Range (min … max):   10.018 s … 10.369 s    20 runs
"""

runs["nothing"] = [
    10.017699517439999,
    10.088123074439999,
    10.08467247644,
    10.16185624644,
    10.319950152439999,
    10.24634284944,
    10.224325387439999,
    10.25004799944,
    10.238360325439999,
    10.203175114439999,
    10.16080226844,
    10.24291256544,
    10.292580317439999,
    10.33936414244,
    10.22172669544,
    10.34077575444,
    10.332503725439999,
    10.36889335744,
    10.25660310144,
    10.22340592144
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 0
Reapply PROT_NONE on splitted pages enabled : 0
Migrate splitted pages enabled : 0
Reset counters on splitted pages enabled : 0

Aggregated results :
Time (mean ± σ):     10.045 s ±  0.154 s    [User: 638.420 s, System: 1.217 s]
Range (min … max):    9.641 s … 10.304 s    20 runs
"""

runs["nb-alone"] = [
    9.93060330792,
    10.16146949492,
    9.82651146192,
    10.08768020392,
    9.93788329792,
    10.11148272392,
    10.07602762692,
    10.01640627192,
    9.64148564792,
    9.95804990492,
    10.16491544592,
    9.90440141392,
    10.00763706292,
    10.06369680592,
    10.13324878992,
    10.296399169919999,
    10.30417058592,
    10.11248161292,
    10.02913133492,
    10.13721467492
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 0
Migrate splitted pages enabled : 0
Reset counters on splitted pages enabled : 0

Aggregated results :
Time (mean ± σ):      9.115 s ±  0.163 s    [User: 576.308 s, System: 2.393 s]
Range (min … max):    8.863 s …  9.523 s    20 runs
"""

runs["split-pages-only"] = [
    8.990761922499999,
    8.865057604499999,
    8.8632662405,
    9.096438641499999,
    8.962837345499999,
    9.0276967985,
    9.0277416135,
    9.2933950575,
    9.0903850255,
    9.0728562785,
    9.1686978575,
    9.0425215495,
    9.1056909715,
    9.438392990499999,
    9.1293011455,
    9.170380612499999,
    9.102214670499999,
    9.1286616875,
    9.194685051499999,
    9.523315370499999
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 1
Migrate splitted pages enabled : 0
Reset counters on splitted pages enabled : 0

Aggregated results :
Time (mean ± σ):      8.994 s ±  0.105 s    [User: 567.358 s, System: 2.949 s]
Range (min … max):    8.830 s …  9.238 s    20 runs
"""

runs["split-reset-prot"] = [
    9.00678122942,
    8.82989754542,
    8.88966593442,
    8.83136648042,
    8.900258948420001,
    9.01219696742,
    8.91595793442,
    9.066698347420001,
    8.98104004042,
    8.93664269642,
    9.03132731142,
    8.997022169420001,
    8.88209353142,
    8.95167948442,
    9.10278793042,
    9.11099185242,
    9.23785202942,
    9.12352299642,
    9.06310185242,
    9.016549921420001
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 1
Migrate splitted pages enabled : 1
Reset counters on splitted pages enabled : 0

Aggregated results :
Time (mean ± σ):      9.065 s ±  0.105 s    [User: 572.042 s, System: 2.746 s]
Range (min … max):    8.886 s …  9.311 s    20 runs
"""

runs["split-all-except-counters"] = [
    9.00890808342,
    8.98465092842,
    9.26770850242,
    8.95039083742,
    8.88582959742,
    9.08103683142,
    9.15769366642,
    9.03865702342,
    9.15682758142,
    8.95122600642,
    9.131368526420001,
    9.024207823420001,
    8.98392485442,
    9.03078342242,
    9.11882481542,
    9.07301659642,
    9.31117805142,
    9.08890596942,
    9.07143852842,
    8.98398568242
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 1
Migrate splitted pages enabled : 0
Reset counters on splitted pages enabled : 1

Aggregated results :
Time (mean ± σ):      9.040 s ±  0.099 s    [User: 570.684 s, System: 2.553 s]
Range (min … max):    8.922 s …  9.297 s    20 runs
"""

runs["split-all-except-migrate-splitted"] = [
    9.015422258860001,
    9.01159534386,
    8.981147827860001,
    8.98439695886,
    9.26700405986,
    8.925696737860001,
    9.01871358786,
    8.985286738860001,
    9.09573036686,
    8.973532693860001,
    9.14226531786,
    9.03454264186,
    9.06871874586,
    8.92207998386,
    8.979498748860001,
    9.003428490860001,
    9.29726268186,
    8.98787633986,
    9.097975420860001,
    9.00151562386
]

# %%
"""
Config :
Machine : dahu-29
Performance governor : performance

Transparent huge pages enabled : [always] madvise never
Transparent huge pages defrag : always defer defer+madvise [madvise] never

OMP_PROC_BIND : true
OMP_PLACES : {0}:64:1

NUMA balancing delay : 150 ms
NUMA balancing min period : 90 ms
NUMA balancing max period : 120 ms

NUMA balancing enabled : 1

Split shared node pages enabled : 1
Reapply PROT_NONE on splitted pages enabled : 1
Migrate splitted pages enabled : 1
Reset counters on splitted pages enabled : 1

Aggregated results :
Time (mean ± σ):      8.976 s ±  0.080 s    [User: 566.520 s, System: 2.664 s]
Range (min … max):    8.869 s …  9.184 s    20 runs
"""

runs["split-all"] = [
    8.86928319016,
    8.94765692616,
    8.98944830716,
    8.87437737916,
    8.943024731160001,
    8.90432068516,
    9.06134689816,
    9.00635234916,
    8.978523247160002,
    8.96552854916,
    8.87200003316,
    8.93940027616,
    8.94630866816,
    8.929543908160001,
    8.96375162016,
    9.003326064160001,
    9.111108148160001,
    9.184281743160001,
    9.062221479160002,
    8.974196328160001
]

# %%
len(runs)
# Out:
# 8

# %%
estimated_time = (len(runs) * 100 * 10) / 3600
estimated_time
# Out:
# 2.2222222222222223
