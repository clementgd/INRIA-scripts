# %% [markdown]
# # Correlation Evaluation

# %%
import matplotlib.pyplot as plt
from typing import Optional, List, Tuple, Dict
import pandas as pd
import os
import re
import json
import subprocess
import numpy as np
from scipy import stats
from collections import defaultdict
import seaborn as sns

# %% [markdown]
# #### Global variables

# %%
TRACE_CMD_CACHE_FILENAME = "trace_cmd_runtimes"
RESULTS_DIR_PATH = "/root/results"
ABSOLUTE_RESULTS_DIR_PATH = "/home/cgachod/analysis/results"
PERF_STAT_SUB_DIR="_perf_stat"

PERF_STAT_RESULTS_EXTENSION = ".txt"

def get_result_dir_path(result_dir_name):
    return os.path.join(RESULTS_DIR_PATH, result_dir_name)

def in_result_dir(path: str):
    return os.path.join(RESULTS_DIR_PATH, path)

def get_absolute_result_dir_path(result_dir_name) :
    return os.path.join(ABSOLUTE_RESULTS_DIR_PATH, result_dir_name)

def in_perf_stat_dir(benchmark_dir_name) :
    return in_result_dir(os.path.join(PERF_STAT_SUB_DIR, benchmark_dir_name))

# %% [markdown]
# #### Visualization params

# %%
nb_enabled_color = "tab:orange"
nb_disabled_color = "tab:blue"

figure_height = 10 # 10
min_figure_width = 40
figure_width_coeff = 0.3

line_width = 1.0

# %%
def init_runs_plot():
    # plt.figure(figsize=(fig_width, 5))
    # plt.legend(loc="upper left")
    plt.xlabel("Nth run")
    plt.ylabel("Run time (seconds)")
    plt.grid(axis="y", which="both")
    plt.grid(axis="x", which="major")
    
    # ax = plt.gca()
    # ax.ticklabel_format(axis="x", useOffset=1.0)

def plot_runs(values: List[float], label = None, color = None, init_plot = True) :
    if init_plot:
        init_runs_plot()
    plt.plot(range(len(values)), values, label=label, color=color, linewidth=line_width)
    
    current_xticks_count = len(plt.xticks()[0])
    if len(values) > current_xticks_count :
        plt.xticks(range(len(values)), rotation=45)
        plt.xlim(-1, len(values))
        
    # candidate_ylim_max = max(values) * 1.2
    # if candidate_ylim_max > plt.ylim()[1] :
    #     plt.ylim(0, candidate_ylim_max)
        
    fig = plt.gcf()
    candidate_width = max(int(len(values) * figure_width_coeff), min_figure_width)
    curr_width = fig.get_size_inches()[0]
    if candidate_width > curr_width :
        fig.set_size_inches(candidate_width, figure_height)
    
    if label :
        plt.legend(loc="upper left")

# %%
def parse_per_cpu_result_file(file_path) -> Tuple[pd.DataFrame, Dict]:
    with open(file_path, 'r') as file:
        text = file.read()
    nas_time_match = re.search(r'Time in seconds\s+=\s+(\d*.\d*)', text)
    if nas_time_match :
        nas_time = float(nas_time_match.group(1))
        
    json_begin_pos = text.find('{')
    json_end_pos = text.rfind('}')
    json_text = text[json_begin_pos:json_end_pos + 1]
    json_lines = json_text.split('\n')
    
    events_df = pd.DataFrame()
    
    meta_values = {"nas_runtime": nas_time}
    
    event_counters: Dict[str, list] = defaultdict(list)
    for line in json_lines :
        json_object = json.loads(line)
        event_str = json_object["event"].strip()
        if event_str in ["duration_time", "user_time", "system_time"] :
            meta_values[event_str] = float(json_object["counter-value"])
        else :
            event_counters[event_str].append((int(json_object["cpu"]), float(json_object["counter-value"])))
    
    events_df = pd.DataFrame({event: [e[1] for e in sorted(values)] for event, values in event_counters.items()})
    if "LLC-load-misses" in events_df and "LLC-store-misses" in events_df and "LLC-loads" in events_df and "LLC-stores" in events_df:
        events_df["LLC-all-misses"] = events_df["LLC-load-misses"] + events_df["LLC-store-misses"]
        events_df["LLC-load-misses-ratio"] = events_df["LLC-load-misses"] / events_df["LLC-loads"]
        events_df["LLC-store-misses-ratio"] = events_df["LLC-store-misses"] / events_df["LLC-stores"]
    
    events_df["ml_l3_mr.all"] = events_df["mem_load_l3_miss_retired.remote_dram"] + events_df["mem_load_l3_miss_retired.local_dram"]
    # events_df["mem_load_l3_miss_retired-over-LLC-all"] = events_df["ml_l3_mr.all"] / events_df["LLC-all-misses"]
    events_df["ml_l3_mr.remote_over_local_dram"] = events_df["mem_load_l3_miss_retired.remote_dram"] / events_df["mem_load_l3_miss_retired.local_dram"]
    events_df["ml_l3_mr.remote_over_total"] = events_df["mem_load_l3_miss_retired.remote_dram"] / events_df["ml_l3_mr.all"]
    events_df["ml_l3_mr.local_over_total"] = events_df["mem_load_l3_miss_retired.local_dram"] / events_df["ml_l3_mr.all"]
    
    # mem_load_l3_miss_retired.remote_fwd
    # mem_load_l3_miss_retired.remote_hitms
    events_df["ml_l3_mr.fwd_over_total"] = events_df["mem_load_l3_miss_retired.remote_fwd"] / events_df["ml_l3_mr.all"]
    events_df["ml_l3_mr.hitm_over_total"] = events_df["mem_load_l3_miss_retired.remote_hitm"] / events_df["ml_l3_mr.all"]
    return events_df, meta_values
    

# TODO Add posibility to specify events ?
def parse_batch_results(dir_path) :
    file_paths = [os.path.join(dir_path, file) for file in os.listdir(dir_path) if file.endswith(PERF_STAT_RESULTS_EXTENSION)]
    concatenated_dict = defaultdict(list)
    for file_path in file_paths :
        events_df, meta_values = parse_per_cpu_result_file(file_path)
        for series_name, series in events_df.items() :
            concatenated_dict[f"min:{series_name}"].append(series.min())
            concatenated_dict[f"max:{series_name}"].append(series.max())
            concatenated_dict[f"sum:{series_name}"].append(series.sum())
            concatenated_dict[f"avg:{series_name}"].append(series.sum() / len(series))
        for key, val in meta_values.items() :
            concatenated_dict[key].append(val)
    return pd.DataFrame(concatenated_dict)



# TODO Maybe return the number of CPUs so that we can compute the average when we have only the sum ?
def parse_batches_results_from_benchmark(benchmark_dir_path: str) -> Dict[str, pd.DataFrame] :
    dfs = {}
    contents = os.listdir(benchmark_dir_path)
    for c in contents :
        dir_path = os.path.join(benchmark_dir_path, c)
        if not os.path.isdir(dir_path) :
            continue
        print(f"Parsing batch in directory {dir_path}")
        dfs[c] = parse_batch_results(dir_path)
    return dfs


def combine_benchmark_dir(benchmark_dir_name) :
    df = pd.DataFrame()
    benchmark_dir_path = get_result_dir_path("_perf/" + benchmark_dir_name)
    contents = os.listdir(benchmark_dir_path)
    for c in contents :
        dir_path = os.path.join(benchmark_dir_path, c)
        if not os.path.isdir(dir_path) :
            continue
        
        df = pd.concat([df, parse_batch_results(dir_path)], ignore_index=True)
    return df

# %%
def plot_event_from_benchmark(all_dfs: Dict[str, pd.DataFrame], aggregated_event: str, variations_only = False) :
    plotting_df = pd.DataFrame({dir: df[aggregated_event] for dir, df in all_dfs.items()})
    means = plotting_df.mean().sort_values()
    sorted_plotting_df = plotting_df[means.index]
    
    if variations_only :
        reference_value = min(means)
        for col in sorted_plotting_df :
            sorted_plotting_df[col] = ((sorted_plotting_df[col] - reference_value) * 100) / reference_value
            
    plt.ylabel("Event value")
    sns.violinplot(data = sorted_plotting_df, inner_kws=dict(box_width=15, whis_width=7, color=".3"))

    plt.gcf().set_size_inches(28, 18)
    plt.xticks(rotation=20, ha='right')
    plt.minorticks_on()
    plt.grid(axis="y", which="major", color='0.2', linestyle='-', linewidth=0.5)
    plt.grid(axis="y", which="minor", color='0.1', linestyle=':', linewidth=0.5)
    plt.scatter(x=range(len(means)),y=means, marker='o', s=30, c="white", alpha=1, zorder=10)
    # plt.grid(axis="x", which="major")
    plt.ylim(bottom=0.0)
    plt.title(aggregated_event)
    plt.show()

# %%
all_dfs = parse_batches_results_from_benchmark(in_perf_stat_dir("cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20"))
# all_dfs = parse_batches_results_from_benchmark(in_perf_stat_dir("cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-19"))
# Out:
# Parsing batch in directory /root/results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-none
# Parsing batch in directory /root/results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sockorder
# Parsing batch in directory /root/results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sequential

# %%
disabled_dfs = {config: df for config, df in all_dfs.items() if "disabled" in config}
all_dfs = disabled_dfs
print(all_dfs.keys())
# Out:
# dict_keys(['nb-disabled-none', 'nb-disabled-sockorder', 'nb-disabled-sequential'])

# %%
for config, df in all_dfs.items():
    print(f"Len of config {config} : {len(df)}")
# Out:
# Len of config nb-disabled-none : 400
# Len of config nb-disabled-sockorder : 200
# Len of config nb-disabled-sequential : 200

# %%
# print(all_dfs.keys())
# all_dfs["nb-disabled-none"]
plot_event_from_benchmark(all_dfs, "avg:ml_l3_mr.fwd_over_total", False)
plot_event_from_benchmark(all_dfs, "avg:ml_l3_mr.remote_over_total", False)
plot_event_from_benchmark(all_dfs, "nas_runtime", False)

# %%
plot_event_from_benchmark(all_dfs, "avg:mem_load_l3_miss_retired.remote_over_total")
plot_event_from_benchmark(all_dfs, "nas_runtime")

list(all_dfs.values())[0].columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_event_from_benchmark(all_dfs, "avg:mem_load_l3_miss_retired.remote_over_total")
#       2 plot_event_from_benchmark(all_dfs, "nas_runtime")
#       4 list(all_dfs.values())[0].columns
#
# NameError: name 'plot_event_from_benchmark' is not defined

# %% [markdown]
# ### Focus on L3 miss categories

# %%
def print_correlations(df: pd.DataFrame, target_column = "nas_runtime"):
    # We first remove all the avg columns if any because will give the same result as sum
    
    avg_columns = [col for col in df.columns if "avg:" in col]
    df = df.drop(avg_columns, axis=1)
    pd.set_option('display.max_rows', 500)
    correlation_df = df.corr()
    correlation_series = correlation_df[target_column].drop(target_column).sort_values(ascending=False, key=abs)

    threshold = 0.98
    previous = []
    for col in correlation_series.index:
        was_dropped = False
        for previous_col in previous:
            # print(correlation_df.loc[col, previous_col])
            if correlation_df.loc[col, previous_col] > threshold:
                # print(f"Found correlation > {threshold} between {col} and {previous_col}")
                correlation_series.drop(col, inplace=True)
                was_dropped = True
                break
        if not was_dropped and "time" not in col:
            previous.append(col)
            
    display(correlation_series)
    # new_df = correlations.to_frame(name = "corr")
    # new_df["abs_corr"] = new_df["corr"].map(lambda x : abs(x))
    # new_df.sort_values(by = "abs_corr", ascending=False)
    # display(correlations.sort_values(ascending=False, key=abs))
    
    
# First within each batch, and then as a whole


def compute_correlations(df: pd.DataFrame, target_column = "nas_runtime", filter_out_intra_correlated = False):
    # We first remove all the avg columns if any because will give the same result as sum
    
    avg_columns = [col for col in df.columns if "avg:" in col]
    df = df.drop(avg_columns, axis=1)
    # pd.set_option('display.max_rows', 500)
    correlation_df = df.corr()
    correlation_series = correlation_df[target_column].drop(target_column).sort_values(ascending=False, key=abs)
    
    if not filter_out_intra_correlated:
        return correlation_series

    threshold = 0.98
    previous = []
    for col in correlation_series.index:
        was_dropped = False
        for previous_col in previous:
            # print(correlation_df.loc[col, previous_col])
            if correlation_df.loc[col, previous_col] > threshold:
                # print(f"Found correlation > {threshold} between {col} and {previous_col}")
                correlation_series.drop(col, inplace=True)
                was_dropped = True
                break
        if not was_dropped and "time" not in col:
            previous.append(col)
            
    return correlation_series

# %%
def print_correlations_for_dfs(dfs):
    concatenated = pd.concat(dfs.values())
    print_correlations(concatenated)
# print_correlations_for_dfs(all_dfs)


pos_color = "skyblue"
neg_color = "salmon"
# pos_color = "tab:blue"
# neg_color = "tab:orange"
correlation_series = compute_relevant_correlations(pd.concat(all_dfs))
# correlation_series = correlation_series[("time" not in correlation_series.index)]
correlation_series = correlation_series[~correlation_series.index.str.contains("time")]
colors = np.array([pos_color] * len(correlation_series), dtype=object)
colors[correlation_series < 0] = neg_color

positive_values = correlation_series[correlation_series >= 0]
negative_values = correlation_series[correlation_series < 0] * -1
# for event in correlation_series.index:
#     print(f"event : {event}, value : {correlation_series[event]}")

plt.bar(correlation_series.index, abs(correlation_series), color=[pos_color if corr > 0 else neg_color for corr in correlation_series], width=0.8)

# memory_load_l3_
custom_labels = ["Sum of ML_l3_M local / total", "Sum of ML_l3_M remote/local"]
plt.xticks(rotation=30, ha='right')
plt.gcf().set_size_inches(15, 6)
plt.grid(axis="y", linewidth=0.5)
plt.title("Correlation Between Events Metrics and Runtime")
plt.ylabel("Correlation Coefficient (between 0 and 1)")

from matplotlib.patches import Patch
positive_patch = Patch(color=pos_color, label='Positive Correlation')
negative_patch = Patch(color=neg_color, label='Negative Correlation')

# Add custom legend to the plot
plt.legend(handles=[positive_patch, negative_patch])

# plt.bar(positive_values.index, positive_values, color='skyblue', label='Positive Correlation')
# plt.bar(negative_values.index, negative_values, color='salmon', label='Negative Correlation')

plt.show()

# sum:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.remote_over_total              0.987359
# sum:mem_load_l3_miss_retired.local_dram    -0.982023
# sum:mem_load_l3_miss_retired.remote_hitm   -0.956419
# max:mem_load_l3_miss_retired.remote_hitm   -0.935753
# max:mem_load_l3_miss_retired.remote_dram    0.930707
# sum:ml_l3_mr.all                           -0.756413
# max:ml_l3_mr.hitm_over_total               -0.742151
# min:ml_l3_mr.hitm_over_total                0.706117
# min:ml_l3_mr.all                           -0.643007
# max:mem_load_l3_miss_retired.local_dram    -0.569269
# max:ml_l3_mr.fwd_over_total                 0.535965
# min:mem_load_l3_miss_retired.remote_hitm    0.482274
# max:ml_l3_mr.all                           -0.472977
# min:mem_load_l3_miss_retired.remote_dram    0.376699
# max:ml_l3_mr.local_over_total              -0.374187
# sum:ml_l3_mr.hitm_over_total                0.334700
# sum:ml_l3_mr.fwd_over_total                 0.310451
# max:mem_load_l3_miss_retired.remote_fwd     0.263584
# min:mem_load_l3_miss_retired.remote_fwd    -0.143863
# min:ml_l3_mr.fwd_over_total                 0.065925
# system_time                                -0.032484
# sum:mem_load_l3_miss_retired.remote_fwd    -0.006071



# avg:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.remote_over_total              0.987359
# avg:ml_l3_mr.remote_over_total              0.987359
# avg:ml_l3_mr.remote_over_local_dram         0.985466
# sum:ml_l3_mr.remote_over_local_dram         0.985466
# sum:mem_load_l3_miss_retired.local_dram    -0.982023
# avg:mem_load_l3_miss_retired.local_dram    -0.982023
# sum:mem_load_l3_miss_retired.remote_dram    0.979381
# avg:mem_load_l3_miss_retired.remote_dram    0.979381
# min:ml_l3_mr.local_over_total              -0.976917
# max:ml_l3_mr.remote_over_total              0.976917
# max:ml_l3_mr.remote_over_local_dram         0.969410
# min:mem_load_l3_miss_retired.local_dram    -0.968579
# sum:mem_load_l3_miss_retired.remote_hitm   -0.956419
# avg:mem_load_l3_miss_retired.remote_hitm   -0.956419
# max:mem_load_l3_miss_retired.remote_hitm   -0.935753
# max:mem_load_l3_miss_retired.remote_dram    0.930707
# sum:ml_l3_mr.all                           -0.756413
# avg:ml_l3_mr.all                           -0.756413
# max:ml_l3_mr.hitm_over_total               -0.742151
# min:ml_l3_mr.hitm_over_total                0.706117
# min:ml_l3_mr.all                           -0.643007
# max:mem_load_l3_miss_retired.local_dram    -0.569269
# max:ml_l3_mr.fwd_over_total                 0.535965
# min:mem_load_l3_miss_retired.remote_hitm    0.482274
# max:ml_l3_mr.all                           -0.472977
# min:mem_load_l3_miss_retired.remote_dram    0.376699
# min:ml_l3_mr.remote_over_total              0.374187
# max:ml_l3_mr.local_over_total              -0.374187
# min:ml_l3_mr.remote_over_local_dram         0.374024
# sum:ml_l3_mr.hitm_over_total                0.334700
# avg:ml_l3_mr.hitm_over_total                0.334700
# sum:ml_l3_mr.fwd_over_total                 0.310451
# avg:ml_l3_mr.fwd_over_total                 0.310451
# max:mem_load_l3_miss_retired.remote_fwd     0.263584
# min:mem_load_l3_miss_retired.remote_fwd    -0.143863
# min:ml_l3_mr.fwd_over_total                 0.065925
# system_time                                -0.032484
# sum:mem_load_l3_miss_retired.remote_fwd    -0.006071
# avg:mem_load_l3_miss_retired.remote_fwd    -0.006071


relevant_events = {
    "sum:ml_l3_mr.remote_over_total": "Sum of ML_l3_M remote / total",
    "max:ml_l3_mr.remote_over_total": "Max of ML_l3_M remote / total",
    "max:ml_l3_mr.hitm_over_total": "Max of ML_l3_M hitm / total", # Hit Modified
    "min:ml_l3_mr.hitm_over_total": "Min of ML_l3_M hitm / total",
    "max:ml_l3_mr.fwd_over_total": "Max of ML_l3_M fwd / total",
    "min:ml_l3_mr.remote_over_total": "Min of ML_l3_M remote / total",
    "sum:ml_l3_mr.hitm_over_total": "Sum of ML_l3_M hitm / total",
    "sum:ml_l3_mr.fwd_over_total": "Sum of ML_l3_M fwd / total"
}

# %%
# compute_correlations()

# relevant_events = {
#     "sum:ml_l3_mr.remote_over_total": "Sum of ML_l3_M remote / total",
#     "max:ml_l3_mr.remote_over_total": "Max of ML_l3_M remote / total",
#     "max:ml_l3_mr.hitm_over_total": "Max of ML_l3_M hitm / total", # Hit Modified
#     "min:ml_l3_mr.hitm_over_total": "Min of ML_l3_M hitm / total",
#     "max:ml_l3_mr.fwd_over_total": "Max of ML_l3_M fwd / total",
#     "min:ml_l3_mr.remote_over_total": "Min of ML_l3_M remote / total",
#     "sum:ml_l3_mr.hitm_over_total": "Sum of ML_l3_M hitm / total",
#     "sum:ml_l3_mr.fwd_over_total": "Sum of ML_l3_M fwd / total"
# }

relevant_events = {
    "max:ml_l3_mr.remote_over_total": "Max of ML_l3_M remote / total",
    "max:ml_l3_mr.hitm_over_total": "Max of ML_l3_M hitm / total", # Hit Modified
    "min:ml_l3_mr.hitm_over_total": "Min of ML_l3_M hitm / total",
    "max:ml_l3_mr.fwd_over_total": "Max of ML_l3_M fwd / total",
    "min:ml_l3_mr.remote_over_total": "Min of ML_l3_M remote / total",
    "sum:ml_l3_mr.hitm_over_total": "Sum of ML_l3_M hitm / total",
    "sum:ml_l3_mr.fwd_over_total": "Sum of ML_l3_M fwd / total",
    "sum:ml_l3_mr.remote_over_total": "Sum of ML_l3_M remote / total"
}
combined_df = pd.concat(all_dfs)
correlation_values = list(compute_correlations(combined_df)[relevant_events.keys()])

events_df = pd.DataFrame({
    "name": relevant_events.keys(),
    "pretty_name": relevant_events.values(),
    "correlation": correlation_values,
    "abs_corr": [abs(corr) for corr in correlation_values]
})
# correlation_series = compute_correlations(pd.concat(all_dfs))[relevant_events.keys()]
# events_df["correlation"] = 
# events_df = pd.concat([events_df, correlation_series.to_frame()])
# events_df
# events_df = events_df[data_df.mean().sort_values().index]
# events_df.sort_values(by = "correlation", key = lambda x: abs(x), ascending=False)

events_df = events_df.sort_values("abs_corr", ascending=False)

pos_color = "tab:blue"
neg_color = "tab:orange"

plt.bar(events_df["pretty_name"], events_df["abs_corr"], 
        color=[pos_color if corr > 0 else neg_color for corr in events_df["correlation"]], 
        width=0.6)

# memory_load_l3_
# custom_labels = ["Sum of ML_l3_M local / total", "Sum of ML_l3_M remote/local"]
plt.xticks(rotation=30, ha='right')
plt.gcf().set_size_inches(12, 6)
plt.grid(axis="y", linewidth=0.5)
plt.title(f"Correlation Between Events Metrics and Runtime - NAS benchmark CG size C on Dual-Node Machine\nAverage Runtime : {round(combined_df['nas_runtime'].mean())} s")
plt.ylabel("Correlation Coefficient (between 0 and 1)")
plt.xlabel("Event metric  -  \"ML_l3_M\" = memory load L3 miss")

from matplotlib.patches import Patch
positive_patch = Patch(color=pos_color, label='Positive Correlation')
negative_patch = Patch(color=neg_color, label='Negative Correlation')

# Add custom legend to the plot
plt.legend(handles=[positive_patch, negative_patch])

# plt.bar(positive_values.index, positive_values, color='skyblue', label='Positive Correlation')
# plt.bar(negative_values.index, negative_values, color='salmon', label='Negative Correlation')

plt.show()

# %%
def plot_correlation_for_combined_df(df):
    correlation_series = compute_relevant_correlations(df)
    # correlation_series = correlation_series[("time" not in correlation_series.index)]
    correlation_series = correlation_series[~correlation_series.index.str.contains("time")]
    colors = np.array(["tab:blue"] * len(correlation_series), dtype=object)
    colors[correlation_series < 0] = "tab:orange"

    positive_values = correlation_series[correlation_series >= 0]
    negative_values = correlation_series[correlation_series < 0] * -1
    # for event in correlation_series.index:
    #     print(f"event : {event}, value : {correlation_series[event]}")

    # plt.bar(correlation_series.index, abs(correlation_series), color=colors, width=0.8)
    # plt.xticks(rotation=30, ha='right')
    # plt.gcf().set_size_inches(15, 6)
    # plt.grid(axis="y", linewidth=0.5)
    # plt.title("Correlation Coefficient of Events With Runtime")

    plt.bar(positive_values.index, positive_values, color='skyblue', label='Positive Correlation')
    plt.bar(negative_values.index, negative_values, color='salmon', label='Negative Correlation')
    plt.xticks(list(correlation_series.index)[:4], rotation=45, ha='right')
    plt.gcf().set_size_inches(15, 6)
    plt.grid(axis="y", linewidth=0.5)
    plt.show()
    
plot_correlation_for_combined_df(pd.concat(all_dfs))

# %%
test_dfs = parse_batches_results_from_benchmark(in_result_dir("_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20"))
concatenated = pd.concat(test_dfs.values())
print_correlations(concatenated)
# Out:
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-none
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sequential
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sockorder
# duration_time                               0.999983
# user_time                                   0.999976
# sum:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.remote_over_total              0.987359
# sum:mem_load_l3_miss_retired.local_dram    -0.982023
# sum:mem_load_l3_miss_retired.remote_hitm   -0.956419
# max:mem_load_l3_miss_retired.remote_hitm   -0.935753
# max:mem_load_l3_miss_retired.remote_dram    0.930707
# sum:ml_l3_mr.all                           -0.756413
# max:ml_l3_mr.hitm_over_total               -0.742151
# min:ml_l3_mr.hitm_over_total                0.706117
# min:ml_l3_mr.all                           -0.643007
# max:mem_load_l3_miss_retired.local_dram    -0.569269
# max:ml_l3_mr.fwd_over_total                 0.535965
# min:mem_load_l3_miss_retired.remote_hitm    0.482274
# max:ml_l3_mr.all                           -0.472977
# min:mem_load_l3_miss_retired.remote_dram    0.376699
# max:ml_l3_mr.local_over_total              -0.374187
# sum:ml_l3_mr.hitm_over_total                0.334700
# sum:ml_l3_mr.fwd_over_total                 0.310451
# max:mem_load_l3_miss_retired.remote_fwd     0.263584
# min:mem_load_l3_miss_retired.remote_fwd    -0.143863
# min:ml_l3_mr.fwd_over_total                 0.065925
# system_time                                -0.032484
# sum:mem_load_l3_miss_retired.remote_fwd    -0.006071
# Name: nas_runtime, dtype: float64

# %%
print_correlations(concatenated, target_column="duration_time")
# Out:
# user_time                                   0.999986
# nas_runtime                                 0.999983
# sum:ml_l3_mr.local_over_total              -0.987873
# sum:ml_l3_mr.remote_over_total              0.987873
# sum:mem_load_l3_miss_retired.local_dram    -0.982095
# sum:mem_load_l3_miss_retired.remote_hitm   -0.957160
# max:mem_load_l3_miss_retired.remote_hitm   -0.935755
# max:mem_load_l3_miss_retired.remote_dram    0.931592
# sum:ml_l3_mr.all                           -0.755298
# max:ml_l3_mr.hitm_over_total               -0.742851
# min:ml_l3_mr.hitm_over_total                0.705345
# min:ml_l3_mr.all                           -0.642081
# max:mem_load_l3_miss_retired.local_dram    -0.568975
# max:ml_l3_mr.fwd_over_total                 0.535045
# min:mem_load_l3_miss_retired.remote_hitm    0.481368
# max:ml_l3_mr.all                           -0.471479
# min:mem_load_l3_miss_retired.remote_dram    0.377754
# max:ml_l3_mr.local_over_total              -0.375178
# sum:ml_l3_mr.hitm_over_total                0.332748
# sum:ml_l3_mr.fwd_over_total                 0.308335
# max:mem_load_l3_miss_retired.remote_fwd     0.262089
# min:mem_load_l3_miss_retired.remote_fwd    -0.146015
# min:ml_l3_mr.fwd_over_total                 0.063837
# system_time                                -0.033547
# sum:mem_load_l3_miss_retired.remote_fwd    -0.008416
# Name: duration_time, dtype: float64

# %%
test_dfs = parse_batches_results_from_benchmark(in_result_dir("_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20"))
concatenated = pd.concat(test_dfs.values())
test_series = concatenated.corr()["nas_runtime"].drop("nas_runtime").sort_values(ascending=False, key=abs)
# print(test_series
# print_correlations(concatenated)
test_series
# Out:
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-none
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sequential
# Parsing batch in directory ../results/_perf_stat/cg.C.x__dahu-11__v6.8.0-rc3__performance__2024-05-20/nb-disabled-sockorder
# duration_time                               0.999983
# user_time                                   0.999976
# avg:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.local_over_total              -0.987359
# sum:ml_l3_mr.remote_over_total              0.987359
# avg:ml_l3_mr.remote_over_total              0.987359
# avg:ml_l3_mr.remote_over_local_dram         0.985466
# sum:ml_l3_mr.remote_over_local_dram         0.985466
# sum:mem_load_l3_miss_retired.local_dram    -0.982023
# avg:mem_load_l3_miss_retired.local_dram    -0.982023
# sum:mem_load_l3_miss_retired.remote_dram    0.979381
# avg:mem_load_l3_miss_retired.remote_dram    0.979381
# min:ml_l3_mr.local_over_total              -0.976917
# max:ml_l3_mr.remote_over_total              0.976917
# max:ml_l3_mr.remote_over_local_dram         0.969410
# min:mem_load_l3_miss_retired.local_dram    -0.968579
# sum:mem_load_l3_miss_retired.remote_hitm   -0.956419
# avg:mem_load_l3_miss_retired.remote_hitm   -0.956419
# max:mem_load_l3_miss_retired.remote_hitm   -0.935753
# max:mem_load_l3_miss_retired.remote_dram    0.930707
# sum:ml_l3_mr.all                           -0.756413
# avg:ml_l3_mr.all                           -0.756413
# max:ml_l3_mr.hitm_over_total               -0.742151
# min:ml_l3_mr.hitm_over_total                0.706117
# min:ml_l3_mr.all                           -0.643007
# max:mem_load_l3_miss_retired.local_dram    -0.569269
# max:ml_l3_mr.fwd_over_total                 0.535965
# min:mem_load_l3_miss_retired.remote_hitm    0.482274
# max:ml_l3_mr.all                           -0.472977
# min:mem_load_l3_miss_retired.remote_dram    0.376699
# min:ml_l3_mr.remote_over_total              0.374187
# max:ml_l3_mr.local_over_total              -0.374187
# min:ml_l3_mr.remote_over_local_dram         0.374024
# sum:ml_l3_mr.hitm_over_total                0.334700
# avg:ml_l3_mr.hitm_over_total                0.334700
# sum:ml_l3_mr.fwd_over_total                 0.310451
# avg:ml_l3_mr.fwd_over_total                 0.310451
# max:mem_load_l3_miss_retired.remote_fwd     0.263584
# min:mem_load_l3_miss_retired.remote_fwd    -0.143863
# min:ml_l3_mr.fwd_over_total                 0.065925
# system_time                                -0.032484
# sum:mem_load_l3_miss_retired.remote_fwd    -0.006071
# avg:mem_load_l3_miss_retired.remote_fwd    -0.006071
# Name: nas_runtime, dtype: float64

# %%
def find_high_correlation_pairs(df, threshold=0.9):
    """
    Find and print pairs of columns in a DataFrame that have a correlation above a certain threshold.
    
    Parameters:
    df (pandas.DataFrame): The DataFrame containing the data.
    threshold (float): The correlation threshold.
    """
    correlation_matrix = df.corr()
    high_corr_pairs = []
    
    for col1 in correlation_matrix.columns:
        for col2 in correlation_matrix.columns:
            if col1 != col2 and abs(correlation_matrix.loc[col1, col2]) > threshold:
                pair = tuple(sorted((col1, col2)))
                if pair not in high_corr_pairs:
                    high_corr_pairs.append(pair)
                    print(f"Pair: {pair}, Correlation: {correlation_matrix.loc[col1, col2]}")

find_high_correlation_pairs(concatenated)
# Out:
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9844750424875752
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9844750424875752
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.947035876671592
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.947035876671592
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: 0.920544977305032
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9156138960713638
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9156138960713638
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.942071814088317
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.957686081740534
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.957686081740534
# Pair: ('max:ml_l3_mr.remote_over_total', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9517206647620262
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9611820476725446
# Pair: ('avg:ml_l3_mr.remote_over_total', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9611820476725446
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'min:ml_l3_mr.local_over_total'), Correlation: 0.951720664762026
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.9611820476725444
# Pair: ('avg:ml_l3_mr.local_over_total', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9611820476725444
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'nas_runtime'), Correlation: -0.9685794752990161
# Pair: ('duration_time', 'min:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9685920310745306
# Pair: ('min:mem_load_l3_miss_retired.local_dram', 'user_time'), Correlation: -0.9687627583454849
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 1.0
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.961634332540463
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.961634332540463
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9281931490294938
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9355418927719534
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9355418927719534
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9432624516763453
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9722068928467215
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9722068928467215
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9530836708473901
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9758301364410858
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9758301364410858
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 0.9530836708473903
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.975830136441086
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: 0.975830136441086
# Pair: ('nas_runtime', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9820225302317125
# Pair: ('duration_time', 'sum:mem_load_l3_miss_retired.local_dram'), Correlation: -0.9820951981695436
# Pair: ('sum:mem_load_l3_miss_retired.local_dram', 'user_time'), Correlation: -0.9821607440667466
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.961634332540463
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'avg:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.961634332540463
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9281931490294938
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9355418927719534
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'avg:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9355418927719534
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9432624516763453
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9722068928467215
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'avg:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9722068928467215
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'max:ml_l3_mr.remote_over_total'), Correlation: -0.9530836708473901
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9758301364410858
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'avg:ml_l3_mr.remote_over_total'), Correlation: -0.9758301364410858
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'min:ml_l3_mr.local_over_total'), Correlation: 0.9530836708473903
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.975830136441086
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'avg:ml_l3_mr.local_over_total'), Correlation: 0.975830136441086
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'nas_runtime'), Correlation: -0.9820225302317125
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'duration_time'), Correlation: -0.9820951981695436
# Pair: ('avg:mem_load_l3_miss_retired.local_dram', 'user_time'), Correlation: -0.9821607440667466
# Pair: ('min:mem_load_l3_miss_retired.remote_dram', 'min:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9992820280532105
# Pair: ('min:mem_load_l3_miss_retired.remote_dram', 'min:ml_l3_mr.remote_over_total'), Correlation: 0.9993002275640949
# Pair: ('max:ml_l3_mr.local_over_total', 'min:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9993002275641005
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9683211204085979
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9683211204085979
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9426040502654192
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9426040502654192
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9808675008061958
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9596582433160719
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9596582433160719
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9760862857719811
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9552863961921177
# Pair: ('avg:ml_l3_mr.remote_over_total', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9552863961921177
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9760862857719809
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9552863961921177
# Pair: ('avg:ml_l3_mr.local_over_total', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9552863961921177
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'nas_runtime'), Correlation: 0.9307067791763063
# Pair: ('duration_time', 'max:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9315918165441812
# Pair: ('max:mem_load_l3_miss_retired.remote_dram', 'user_time'), Correlation: 0.9311164151617418
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 1.0
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9313919290813465
# Pair: ('sum:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9760143847270158
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9760143847270158
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9857472923926724
# Pair: ('sum:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9987610645805505
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9987610645805505
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9887607641899255
# Pair: ('sum:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9977613181622005
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9977613181622005
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9887607641899254
# Pair: ('sum:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9977613181622004
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: -0.9977613181622004
# Pair: ('nas_runtime', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9793807213501575
# Pair: ('duration_time', 'sum:mem_load_l3_miss_retired.remote_dram'), Correlation: 0.9800465399919525
# Pair: ('sum:mem_load_l3_miss_retired.remote_dram', 'user_time'), Correlation: 0.9798101546925516
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9313919290813465
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9760143847270158
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'avg:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9760143847270158
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9857472923926724
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9987610645805505
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'avg:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9987610645805505
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9887607641899255
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9977613181622005
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'avg:ml_l3_mr.remote_over_total'), Correlation: 0.9977613181622005
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9887607641899254
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9977613181622004
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'avg:ml_l3_mr.local_over_total'), Correlation: -0.9977613181622004
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'nas_runtime'), Correlation: 0.9793807213501575
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'duration_time'), Correlation: 0.9800465399919525
# Pair: ('avg:mem_load_l3_miss_retired.remote_dram', 'user_time'), Correlation: 0.9798101546925516
# Pair: ('min:mem_load_l3_miss_retired.remote_fwd', 'sum:mem_load_l3_miss_retired.remote_fwd'), Correlation: 0.9576373821563637
# Pair: ('avg:mem_load_l3_miss_retired.remote_fwd', 'min:mem_load_l3_miss_retired.remote_fwd'), Correlation: 0.9576373821563637
# Pair: ('min:mem_load_l3_miss_retired.remote_fwd', 'min:ml_l3_mr.fwd_over_total'), Correlation: 0.9610464167479944
# Pair: ('avg:mem_load_l3_miss_retired.remote_fwd', 'sum:mem_load_l3_miss_retired.remote_fwd'), Correlation: 1.0
# Pair: ('min:ml_l3_mr.fwd_over_total', 'sum:mem_load_l3_miss_retired.remote_fwd'), Correlation: 0.9619139713343596
# Pair: ('sum:mem_load_l3_miss_retired.remote_fwd', 'sum:ml_l3_mr.fwd_over_total'), Correlation: 0.9407228977584867
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'sum:mem_load_l3_miss_retired.remote_fwd'), Correlation: 0.9407228977584867
# Pair: ('avg:mem_load_l3_miss_retired.remote_fwd', 'min:ml_l3_mr.fwd_over_total'), Correlation: 0.9619139713343596
# Pair: ('avg:mem_load_l3_miss_retired.remote_fwd', 'sum:ml_l3_mr.fwd_over_total'), Correlation: 0.9407228977584867
# Pair: ('avg:mem_load_l3_miss_retired.remote_fwd', 'avg:ml_l3_mr.fwd_over_total'), Correlation: 0.9407228977584867
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.936827766854353
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.936827766854353
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9136228710512267
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9368157014028885
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9368157014028885
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'max:ml_l3_mr.remote_over_total'), Correlation: -0.9232210110877005
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9390822068286404
# Pair: ('avg:ml_l3_mr.remote_over_total', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9390822068286404
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'min:ml_l3_mr.local_over_total'), Correlation: 0.9232210110877007
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.9390822068286405
# Pair: ('avg:ml_l3_mr.local_over_total', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9390822068286405
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'nas_runtime'), Correlation: -0.9357525804771274
# Pair: ('duration_time', 'max:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9357551075585747
# Pair: ('max:mem_load_l3_miss_retired.remote_hitm', 'user_time'), Correlation: -0.9357088581670928
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 1.0
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9613058198802822
# Pair: ('sum:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9776588816200849
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9776588816200849
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9659301040210135
# Pair: ('sum:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9777618079529552
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9777618079529552
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9659301040210135
# Pair: ('sum:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.9777618079529554
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: 0.9777618079529554
# Pair: ('nas_runtime', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.956418615416959
# Pair: ('duration_time', 'sum:mem_load_l3_miss_retired.remote_hitm'), Correlation: -0.9571595006786532
# Pair: ('sum:mem_load_l3_miss_retired.remote_hitm', 'user_time'), Correlation: -0.9567406765780987
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9613058198802822
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9776588816200849
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'avg:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9776588816200849
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'max:ml_l3_mr.remote_over_total'), Correlation: -0.9659301040210135
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9777618079529552
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'avg:ml_l3_mr.remote_over_total'), Correlation: -0.9777618079529552
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'min:ml_l3_mr.local_over_total'), Correlation: 0.9659301040210135
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.9777618079529554
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'avg:ml_l3_mr.local_over_total'), Correlation: 0.9777618079529554
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'nas_runtime'), Correlation: -0.956418615416959
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'duration_time'), Correlation: -0.9571595006786532
# Pair: ('avg:mem_load_l3_miss_retired.remote_hitm', 'user_time'), Correlation: -0.9567406765780987
# Pair: ('min:ml_l3_mr.all', 'sum:ml_l3_mr.all'), Correlation: 0.911779400864883
# Pair: ('avg:ml_l3_mr.all', 'min:ml_l3_mr.all'), Correlation: 0.911779400864883
# Pair: ('max:ml_l3_mr.all', 'sum:ml_l3_mr.fwd_over_total'), Correlation: -0.9109868476302655
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'max:ml_l3_mr.all'), Correlation: -0.9109868476302655
# Pair: ('max:ml_l3_mr.all', 'sum:ml_l3_mr.hitm_over_total'), Correlation: -0.9266355630090851
# Pair: ('avg:ml_l3_mr.hitm_over_total', 'max:ml_l3_mr.all'), Correlation: -0.9266355630090851
# Pair: ('avg:ml_l3_mr.all', 'sum:ml_l3_mr.all'), Correlation: 1.0
# Pair: ('min:ml_l3_mr.hitm_over_total', 'sum:ml_l3_mr.all'), Correlation: -0.9050633764489946
# Pair: ('avg:ml_l3_mr.all', 'min:ml_l3_mr.hitm_over_total'), Correlation: -0.9050633764489946
# Pair: ('min:ml_l3_mr.remote_over_local_dram', 'min:ml_l3_mr.remote_over_total'), Correlation: 0.9999997686620092
# Pair: ('max:ml_l3_mr.local_over_total', 'min:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9999997686620148
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9844132930240257
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9844132930240257
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9986818575137052
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9828983052652064
# Pair: ('avg:ml_l3_mr.remote_over_total', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9828983052652064
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9986818575137054
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9828983052652063
# Pair: ('avg:ml_l3_mr.local_over_total', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9828983052652063
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'nas_runtime'), Correlation: 0.969409547149483
# Pair: ('duration_time', 'max:ml_l3_mr.remote_over_local_dram'), Correlation: 0.969954932092706
# Pair: ('max:ml_l3_mr.remote_over_local_dram', 'user_time'), Correlation: 0.9697081643566399
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 1.0
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9888362730658101
# Pair: ('sum:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9997583767126499
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9997583767126499
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9888362730658101
# Pair: ('sum:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9997583767126497
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9997583767126497
# Pair: ('nas_runtime', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9854658056554612
# Pair: ('duration_time', 'sum:ml_l3_mr.remote_over_local_dram'), Correlation: 0.9860210125785652
# Pair: ('sum:ml_l3_mr.remote_over_local_dram', 'user_time'), Correlation: 0.9858286722952371
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9888362730658101
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9997583767126499
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'avg:ml_l3_mr.remote_over_total'), Correlation: 0.9997583767126499
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9888362730658101
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9997583767126497
# Pair: ('avg:ml_l3_mr.local_over_total', 'avg:ml_l3_mr.remote_over_local_dram'), Correlation: -0.9997583767126497
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'nas_runtime'), Correlation: 0.9854658056554612
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'duration_time'), Correlation: 0.9860210125785652
# Pair: ('avg:ml_l3_mr.remote_over_local_dram', 'user_time'), Correlation: 0.9858286722952371
# Pair: ('max:ml_l3_mr.local_over_total', 'min:ml_l3_mr.remote_over_total'), Correlation: -1.000000000000005
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9880473672875097
# Pair: ('avg:ml_l3_mr.remote_over_total', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9880473672875097
# Pair: ('max:ml_l3_mr.remote_over_total', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9999999999999999
# Pair: ('max:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9880473672875095
# Pair: ('avg:ml_l3_mr.local_over_total', 'max:ml_l3_mr.remote_over_total'), Correlation: -0.9880473672875095
# Pair: ('max:ml_l3_mr.remote_over_total', 'nas_runtime'), Correlation: 0.9769173596554029
# Pair: ('duration_time', 'max:ml_l3_mr.remote_over_total'), Correlation: 0.9774069052375256
# Pair: ('max:ml_l3_mr.remote_over_total', 'user_time'), Correlation: 0.977198571786001
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.remote_over_total'), Correlation: 1.0
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_total'), Correlation: -0.9880473672875099
# Pair: ('sum:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_total'), Correlation: -1.0000000000000002
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.remote_over_total'), Correlation: -1.0000000000000002
# Pair: ('nas_runtime', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.987359268621985
# Pair: ('duration_time', 'sum:ml_l3_mr.remote_over_total'), Correlation: 0.9878734733243615
# Pair: ('sum:ml_l3_mr.remote_over_total', 'user_time'), Correlation: 0.9876971573344829
# Pair: ('avg:ml_l3_mr.remote_over_total', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9880473672875099
# Pair: ('avg:ml_l3_mr.remote_over_total', 'sum:ml_l3_mr.local_over_total'), Correlation: -1.0000000000000002
# Pair: ('avg:ml_l3_mr.local_over_total', 'avg:ml_l3_mr.remote_over_total'), Correlation: -1.0000000000000002
# Pair: ('avg:ml_l3_mr.remote_over_total', 'nas_runtime'), Correlation: 0.987359268621985
# Pair: ('avg:ml_l3_mr.remote_over_total', 'duration_time'), Correlation: 0.9878734733243615
# Pair: ('avg:ml_l3_mr.remote_over_total', 'user_time'), Correlation: 0.9876971573344829
# Pair: ('min:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.local_over_total'), Correlation: 0.98804736728751
# Pair: ('avg:ml_l3_mr.local_over_total', 'min:ml_l3_mr.local_over_total'), Correlation: 0.98804736728751
# Pair: ('min:ml_l3_mr.local_over_total', 'nas_runtime'), Correlation: -0.976917359655403
# Pair: ('duration_time', 'min:ml_l3_mr.local_over_total'), Correlation: -0.9774069052375259
# Pair: ('min:ml_l3_mr.local_over_total', 'user_time'), Correlation: -0.9771985717860013
# Pair: ('avg:ml_l3_mr.local_over_total', 'sum:ml_l3_mr.local_over_total'), Correlation: 1.0
# Pair: ('nas_runtime', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9873592686219852
# Pair: ('duration_time', 'sum:ml_l3_mr.local_over_total'), Correlation: -0.9878734733243615
# Pair: ('sum:ml_l3_mr.local_over_total', 'user_time'), Correlation: -0.9876971573344832
# Pair: ('avg:ml_l3_mr.local_over_total', 'nas_runtime'), Correlation: -0.9873592686219852
# Pair: ('avg:ml_l3_mr.local_over_total', 'duration_time'), Correlation: -0.9878734733243615
# Pair: ('avg:ml_l3_mr.local_over_total', 'user_time'), Correlation: -0.9876971573344832
# Pair: ('min:ml_l3_mr.fwd_over_total', 'sum:ml_l3_mr.fwd_over_total'), Correlation: 0.935491211603324
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'min:ml_l3_mr.fwd_over_total'), Correlation: 0.935491211603324
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'sum:ml_l3_mr.fwd_over_total'), Correlation: 1.0
# Pair: ('sum:ml_l3_mr.fwd_over_total', 'sum:ml_l3_mr.hitm_over_total'), Correlation: 0.9757184248798988
# Pair: ('avg:ml_l3_mr.hitm_over_total', 'sum:ml_l3_mr.fwd_over_total'), Correlation: 0.9757184248798988
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'sum:ml_l3_mr.hitm_over_total'), Correlation: 0.9757184248798988
# Pair: ('avg:ml_l3_mr.fwd_over_total', 'avg:ml_l3_mr.hitm_over_total'), Correlation: 0.9757184248798988
# Pair: ('avg:ml_l3_mr.hitm_over_total', 'sum:ml_l3_mr.hitm_over_total'), Correlation: 1.0
# Pair: ('duration_time', 'nas_runtime'), Correlation: 0.9999825491720443
# Pair: ('nas_runtime', 'user_time'), Correlation: 0.9999756737888545
# Pair: ('duration_time', 'user_time'), Correlation: 0.9999860183314526

# %% [markdown]
# TODOs :
# - Try and focus on the worst core instead of showing an average across all cores
